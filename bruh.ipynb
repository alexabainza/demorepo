# %%
import csv
import pandas as pd
import os
import glob
from functools import reduce

# %%
path = "C:\\Users\\Alex\\Documents\\New folder\\gois"

all_files = glob.glob(os.path.join(path, "*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged   = pd.concat(df_from_each_file, ignore_index=True)
df_merged.to_csv("merged-beech.csv")

# %%
afs = pd.read_csv(r"C:\Users\Alex\Documents\New folder\merged-beech.csv", encoding = 'latin1')
aa = pd.DataFrame(afs)
aa
# Out:
# C:\Users\Alex\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0 housebill_id                             author committee  \
# 0            4400      HR02364               Barba, Angelo Marcos  ACCOUNTS
# 1            4513      HR02364             Barbers, Robert Ace S.  ACCOUNTS
# 2            5936      HR00150        Benitez, Francisco Kiko  B.  ACCOUNTS
# 3           12011      HR02349  Crisologo, Anthony Peter Onyx  D.  ACCOUNTS
# 4           15724      HR01290         Deloso-Montalla, Cheryl P.  ACCOUNTS
# ...           ...          ...                                ...       ...
# 52640       52407      HR02558          Zarate, Carlos Isagani T.       NaN
# 52641       52408      HR02561          Zarate, Carlos Isagani T.       NaN
# ...

# %%
afs.committee.unique()
# Out:
# array(['JUSTICE', 'BASIC EDUCATION AND CULTURE', 'REVISION OF LAWS',
#        'WAYS AND MEANS', 'HEALTH', 'RULES', 'TRADE AND INDUSTRY',
#        'APPROPRIATIONS', 'ECOLOGY',
#        'INFORMATION AND COMMUNICATIONS TECHNOLOGY',
#        'GOVERNMENT REORGANIZATION', 'NATURAL RESOURCES',
#        'GAMES AND AMUSEMENTS', 'HUMAN RIGHTS',
#        'BANKS AND FINANCIAL INTERMEDIARIES', 'THE WHOLE HOUSE',
#        'DEFEAT COVID-19 AD-HOC COMMITTEE', 'LEGISLATIVE FRANCHISES',
#        'OVERSEAS WORKERS AFFAIRS', 'POPULATION AND FAMILY RELATIONS',
#        'WOMEN AND GENDER EQUALITY', 'PUBLIC INFORMATION',
#        'ECONOMIC AFFAIRS', 'GOVERNMENT ENTERPRISES AND PRIVATIZATION',
#        'DISASTER RESILIENCE', 'HIGHER AND TECHNICAL EDUCATION',
#        'LOCAL GOVERNMENT', 'SENIOR CITIZENS',
#        'GOOD GOVERNMENT AND PUBLIC ACCOUNTABILITY',
#        'LABOR AND EMPLOYMENT', 'PEACE, RECONCILIATION AND UNITY',
#        'SUFFRAGE AND ELECTORAL REFORMS', 'PUBLIC ORDER AND SAFETY',
# ...

# %%
aa.groupby('committee')

# %%
beech = afs[afs.committee=='JUSTICE']

# %%
beech.value_counts('author')
# Out:
# author
# Veloso, Vicente III Ching S.E.    78
# Rodriguez, Rufus B.               71
# Gonzaga, Ruwel Peter S.           49
# Bordado, Gabriel Jr. H.           48
# Zarate, Carlos Isagani T.         47
#                                   ..
# Gonzales, Neptali II M.            1
# Co, Angelica Natasha               1
# Chungalao, Solomon R.              1
# Teves, Jose Jr. Bong J.            1
# Ebcas, Adriano A.                  1
# Length: 244, dtype: int64

# %%
list = afs.committee.unique()
for item in list:
    beech = afs[afs.committee==item]
    print(item)
    print(beech.value_counts('author'))
# Out:
# ACCOUNTS
# author
# Savellano, Deogracias Victor DV B.    2
# Barba, Angelo Marcos                  1
# Barbers, Robert Ace S.                1
# Benitez, Francisco Kiko  B.           1
# Crisologo, Anthony Peter Onyx  D.     1
# Deloso-Montalla, Cheryl P.            1
# Eriguel, Sandra Y., M.D.              1
# Madrona, Eleandro Jesus F.            1
# Paduano, Joseph Stephen Caraps S.     1
# Reyes, Allan Benedict S.              1
# Robes, Florida Rida P.                1
# Romualdez, Ferdinand Martin G.        1
# Silverio, Lorna C.                    1
# Singson-Meehan, Kristine              1
# Velasco, Lord Allan Jay Q.            1
# Yap, Eric Go                          1
# dtype: int64
# AD HOC COMMITTEE ON THE MILITARY AND UNIFORMED PERSONNEL(MUP) PENSION SYSTEM
# author
# Biazon, Ruffy B.                                     3
# Suarez, David Jay-Jay C.                             3
# Salceda, Joey Sarte                                  3
# ...

# %%
directory = 'C:\\Users\\Alex\\Documents\\New folder\\gois2'
big=[]
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    
    if os.path.isfile(f):
        numlist = []
        notice = pd.read_csv(f, encoding = 'latin1')
        numenbills = len(notice[notice['status'].str.contains("enacted", na=False)])
#         print(f'{f} Number enacted bills {numenbills}/{notice.shape[0]}')
        numlist.append(str(filename).replace('.csv',''))
        numlist.append(numenbills)
        numlist.append(f'{notice.shape[0]}')
    big.append(numlist)
    
filedbillscount = pd.DataFrame(data = big, columns =['author', 'enactedbills', 'count/total'])
# filedbillscount = filedbillscount.sort_values(by=['enactedbills'])
filedbillscount.to_csv('EnactedBills.csv', index= False)

# %%
directory = 'C:\\Users\\Alex\\Documents\\New folder\\gois'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    lala = []
    if os.path.isfile(f):
        name = str(filename).replace('.csv','')
        big=[]
        notice = pd.read_csv(f, encoding = 'latin1')
        numenbills = notice[notice['status'].str.contains("enacted", na=False)]
#         print(f'{f} Number enacted bills {numenbills}/{notice.shape[0]}')
#         numlist.append(numenbills)
        numenbills.to_csv(f'{name}.csv', index=False)

# %%
path = "C:\\Users\\Alex\\Documents\\New folder\\gois4"

all_files = glob.glob(os.path.join(path, "*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged   = pd.concat(df_from_each_file, ignore_index=True)
df_merged.to_csv("merged-nana.csv")

# %%
lala=pd.read_csv(r"C:\Users\Alex\Documents\New folder\merged-nana.csv", encoding = 'latin1')

# %%
numenbills = lala[lala['status'].str.contains("enacted", na=False)]
numenbills['committee'].value_counts()

# lala['committee'].value_counts()

# %%
directory1 = 'C:\\Users\\Alex\\Documents\\New folder\\gois2'
big=[]
for filename1 in os.listdir(directory1):
    name = str(filename1).replace('.csv','')
    g = os.path.join(directory1, filename1)
    lala = pd.read_csv(g, encoding ='latin1')
    numenbills = lala[lala['status'].str.contains("enacted", na=False)]
    haha = numenbills['committee'].value_counts()
    big.append(haha)

# %%
directory2 = 'C:\\Users\\Alex\\Documents\\New folder\\sendhelpls'

for filename2 in os.listdir(directory2):
    name = str(filename2).replace('-COMMCOUNT.csv','')
    h = os.path.join(directory2, filename2)
    lala = pd.read_csv(h, encoding ='latin1')
    lala.columns = ['committee_name', 'count']
    lala['author']=name
    lala.to_csv(f'{name}-count.csv', index = False)

# %%
path = "C:\\Users\\Alex\\Documents\\New folder\\gois3"

all_files = glob.glob(os.path.join(path, "*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged   = pd.concat(df_from_each_file, ignore_index=True)
df_merged.to_csv("merged-committee.csv")

# %%
directory = 'C:\\Users\\Alex\\Documents\\New folder\\gois2'
#for each file
for filename in os.listdir(directory):
    
    f = os.path.join(directory, filename)
    # checking if it is a file
    numlist = []
    if os.path.isfile(f):
        fine={}
        notice = pd.read_csv(f, encoding = 'latin1')
        numenbills = len(notice[notice['status'].str.contains("enacted", na=False)])
        fine['author']=str(filename).replace('.csv','')
        fine['enactedBillsCount'] = numenbills
        fine['count/total'] = (f'{numenbills}/{notice.shape[0]}')
        
        numlist.append(fine)
    
    df=pd.DataFrame(numlist)
    print(df)

# %%
afs = pd.read_csv(r"C:\Users\Alex\Documents\New folder\merged-committee.csv", encoding = 'latin1')
baba = afs.sort_values(by = ['committee_name', 'count'], ascending=False)
baba.to_csv('byCommittee.csv', index = False)

# %%
# enacted = lala["enacted" in lala['status'] or "Republic Act" in lala['status']]
len(lala[lala['status'].str.contains("enacted")])

# %%
lala.sort_values(by=['committee'])

# %%
enacted
